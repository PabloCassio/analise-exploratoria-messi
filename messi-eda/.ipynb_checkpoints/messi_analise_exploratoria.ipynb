# %% [markdown]
# # Análise de Dados Exploratória de Lionel Messi
#
# ![messi](img/messi.png "Lionel Messi comemorando título da Copa do Mundo com seus companheiros. Image By: fifa.com")

# %% [markdown]
# # 1. Introdução
#
# Lionel Andrés Messi Cuccittini é um renomado jogador de futebol argentino, conhecido por suas habilidades excepcionais e conquistas no esporte. Desde sua estreia até o dia 03/04/2023, Messi se destacou marcando um número impressionante de gols ao longo de sua carreira.
#
# Neste estudo, iremos explorar um conjunto de dados detalhando os gols marcados por Lionel Messi em partidas oficiais. Os dados abrangem desde o início de sua carreira até a data mencionada, proporcionando uma visão abrangente dos feitos do jogador ao longo do tempo. Essas informações são valiosas para entender a magnitude de suas conquistas e seu impacto no mundo do futebol.
#
# O conjunto de dados foi compilado e atualizado por Azmine Toushik Wasi na plataforma [Kaggle](https://www.kaggle.com/datasets/azminetoushikwasi/-lionel-messi-all-club-goals), incluindo registros de jogos, relatórios esportivos e estatísticas oficiais. Ele apresenta detalhes sobre as partidas em que Messi marcou gols, incluindo a temporada, competição, jornada, data, local, clube pelo qual Messi marcou o gol, adversário, resultado da partida, posição que Messi jogou no campo, minuto, qual o placar a partir do gol de Lionel Messi, tipo de gol marcado e o jogador que deu a assistência para oa gol.
#
# Ao analisar esses dados, poderemos descobrir padrões, tendências e marcos notáveis ​​associados ao desempenho de Messi, permitindo uma apreciação mais profunda de suas habilidades e realizações no mundo do futebol.

# %% [markdown]
# ## 1.1. Objetivos
#
# O objetivo deste estudo é realizar uma Análise Exploratória dos Dados (Exploratory Data Analysis - EDA) do conjunto de dados `messi`, adaptado pelo autor e disponível em [data/messi.csv](data/messi.csv); a fim de caracterizar quais tipos de gols Messi mais marcou, em qual período e faixa de tempo Messi mais marcou, principais assistentes, por qual clube ele mais marcou e quais clubes adversários sofreram mais gols de Lionel Messi. Especificamente serão respondidas as seguintes questões de pesquisa:
#
# 1. [Em quais clubes adversários Messi mais marcou em cada competição que ele disputou?](#3.1.-Qual-é-o-número-de-Sobreviventes?)
# 2. [Quais tipos de gols Messi mais marcou?](#3.2.-Homens-ou-mulheres-tiveram-mais-chances-de-sobreviver?)
# 3. [Quantos gols em cada período (primeiro ou segundo tempo) Messi marcou?](#3.3.-Qual-classe-social-teve-mais-sobreviventes?)
# 4. [Em quais faixas de minuto (divididos a cada 15 minutos) Messi mais marcou?](#3.4.-Qual-faixa-etária-teve-mais-chances-de-sobreviver?)
# 5. [Quais jogadores deram mais assistências para gols de Lionel Messi?](#3.5.-Qual-faixa-etária-teve-mais-chances-de-sobreviver?)

# %% [markdown]
# # 2. Metodologia
#
# Nesta seção será apresentado todo o processo de preparação, organização e limpeza de dados feito no *dataset* que possui os seguintes dados:
#
# | Coluna          | Descrição                                                                 |
# |-----------------|---------------------------------------------------------------------------|
# | id_gol          | Identficador único do gol marcado.                                        |
# | temporada       | Época em que o gol foi marcado.                                           |
# | competicao      | Qual era o campeonato que o gol foi marcado.                              |
# | rodada_comp     | Em qual estágio estava a competição.                                      |
# | data            |  Data que o gol foi marcado                                               |
# | local           | Se Messi jogava no estádio do seu time (H) ou do adversário (A)           |
# | clube           | Por qual clube Messi jogava quando marcou o gol.                          |
# | adversario      | Clube adversário que Messi marcou o gol.                                  |
# | placar          | Placar final da partida.                                                  |
# | posicao_campo   | Em qual posição Messi jogava quando marcou o gol.                         |
# | minuto          | Em qual minuto da partida Messi jogava quando marcou o gol.               |
# | placar_pos_gol  | Qual foi o placar pós gol de Messi.                                       |
# | tipo            | Tipo de gol marcado.                                                      |
# | jogador_ast     | Jogador que deu o passe para o gol.                                       |
#
# ## OBSERVAÇÕES
#
# - `temporada` está divida em em dois anos diferentes, representando o começo da temporada em um ano e o fim da temporada no outro;
# - `local` é uma definição se o estádio em qual Messi jogava estava com mando de campo do clube em que atuava (H) ou do clube adversário (A);
# - `minuto` está representada em faixas de números de 1 a 90, onde o fim do primeiro tempo se dá aos 45 e o fim do segundo aos 90, sendo possível conter acréscimos pós fim de cada tempo representados pelo símbolo "+" e um número que representa o acréscimo em minutos. Contém também minutos pós o período normal de 90 minutos, chamados de prorrogação, em casos de competições especiais que exigem um vencedor por diferença de gols;
# - `tipo` se refere ao estilo de gol marcado por Messi, dividos em::
#     - **Peito**: Gol marcado de peito;
#     - **Gol em contra ataque**: Gol marcado em jogada de contra ataque;
#     - **Chute com o pe esquedo**: Chute de pé esquerdo;
#     - **Chute com o pe direito**:  Chute de pé direito;
#     - **Arrancada**: Jogada partindo de um ponto inicial que contém mais toques na bola de Messi do que outro jogador;
#     - **Cabecada**: Gol marcado de cabeça;
#     - **Penalti**: Gol marcado em cobrança de penâlti;
#     - **Cobranca de falta**: Gol marcado em cobrança de falta;
#     - **Toque sutil**: Desvio leve para o gol;
#     - **Gol em contra ataque**: Gol partindo de erro do adversário no campo de defesa do clube de Messi;
#     - **Penalti**: Gol marcado em rebote de cobrança de penâlti;
#     - **Desviando chute ao gol**: Desvio de Messi em finalização rumo ao gol de outro jogador;

# %% [markdown]
# # 3. Análise dos Dados

# %% [markdown]
# # 3.1 Em quais clubes adversários Messi mais marcou em cada competição que ele disputou?

# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: asttokens==2.2.1 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: backcall==0.2.0 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: certifi==2023.5.7 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 3)) (2023.5.7)
# Requirement already satisfied: charset-normalizer==3.1.0 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 4)) (3.1.0)
# Requirement already satisfied: colorama==0.4.6 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 5)) (0.4.6)
# Requirement already satisfied: comm==0.1.3 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 6)) (0.1.3)
# Requirement already satisfied: debugpy==1.6.7 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 7)) (1.6.7)
# Requirement already satisfied: decorator==5.1.1 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 8)) (5.1.1)
# Requirement already satisfied: docopt==0.6.2 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 9)) (0.6.2)
# Requirement already satisfied: executing==1.2.0 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 10)) (1.2.0)
# Requirement already satisfied: idna==3.4 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 11)) (3.4)
# Requirement already satisfied: ipykernel==6.22.0 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 12)) (6.22.0)
# Requirement already satisfied: ipython==8.13.2 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 13)) (8.13.2)
# Requirement already satisfied: jedi==0.18.2 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 14)) (0.18.2)
# Requirement already satisfied: jupyter_client==8.2.0 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 15)) (8.2.0)
# Requirement already satisfied: jupyter_core==5.3.0 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 16)) (5.3.0)
# Requirement already satisfied: matplotlib-inline==0.1.6 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 17)) (0.1.6)
# Collecting matplotlib
#   Downloading matplotlib-3.7.1-cp311-cp311-win_amd64.whl (7.6 MB)
#      ---------------------------------------- 7.6/7.6 MB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: nest-asyncio==1.5.6 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 19)) (1.5.6)
# Requirement already satisfied: numpy==1.24.3 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 20)) (1.24.3)
# Requirement already satisfied: packaging==23.1 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 21)) (23.1)
# Requirement already satisfied: pandas==2.0.2 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 22)) (2.0.2)
# Requirement already satisfied: parso==0.8.3 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 23)) (0.8.3)
# Requirement already satisfied: pickleshare==0.7.5 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 24)) (0.7.5)
# Requirement already satisfied: pipreqs==0.4.13 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 25)) (0.4.13)
# Requirement already satisfied: platformdirs==3.5.0 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 26)) (3.5.0)
# Requirement already satisfied: prompt-toolkit==3.0.38 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 27)) (3.0.38)
# Requirement already satisfied: psutil==5.9.5 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 28)) (5.9.5)
# Requirement already satisfied: pure-eval==0.2.2 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 29)) (0.2.2)
# Requirement already satisfied: Pygments==2.15.1 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 30)) (2.15.1)
# Requirement already satisfied: python-dateutil==2.8.2 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 31)) (2.8.2)
# Requirement already satisfied: pytz==2023.3 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 32)) (2023.3)
# Requirement already satisfied: pywin32==306 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 33)) (306)
# Requirement already satisfied: pyzmq==25.0.2 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 34)) (25.0.2)
# Requirement already satisfied: requests==2.31.0 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 35)) (2.31.0)
# Requirement already satisfied: six==1.16.0 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 36)) (1.16.0)
# Requirement already satisfied: stack-data==0.6.2 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 37)) (0.6.2)
# Requirement already satisfied: tornado==6.3.1 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 38)) (6.3.1)
# Requirement already satisfied: traitlets==5.9.0 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 39)) (5.9.0)
# Requirement already satisfied: tzdata==2023.3 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 40)) (2023.3)
# Requirement already satisfied: urllib3==2.0.2 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 41)) (2.0.2)
# Requirement already satisfied: wcwidth==0.2.6 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 42)) (0.2.6)
# Requirement already satisfied: yarg==0.1.9 in c:\users\pablo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 43)) (0.1.9)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.7-cp311-cp311-win_amd64.whl (162 kB)
#      ------------------------------------ 163.0/163.0 kB 812.4 kB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.39.4-py3-none-any.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 1.8 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp311-cp311-win_amd64.whl (55 kB)
#      ---------------------------------------- 55.4/55.4 kB 2.8 MB/s eta 0:00:00
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.5.0-cp311-cp311-win_amd64.whl (2.5 MB)
#      ---------------------------------------- 2.5/2.5 MB 1.7 MB/s eta 0:00:00
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      -------------------------------------- 98.3/98.3 kB 208.8 kB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.0.7 cycler-0.11.0 fonttools-4.39.4 kiwisolver-1.4.4 matplotlib-3.7.1 pillow-9.5.0 pyparsing-3.0.9
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: C:\Users\Pablo\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("data/messi.csv")
competicoes= df['competicao'].unique()
for competicao in competicoes:
  df_competicao_desejada = df[df['competicao'] == competicao]
  exibir = df_competicao_desejada['adversario'].value_counts()
  exibir = exibir.head(5)
  exibir.plot(kind='bar')
  plt.xlabel('Adversário')
  plt.ylabel('Quantidade de Gols')
  plt.yticks(range(1, max(exibir.values) +1 ))
  plt.title((f"Exibindo os adversários que Messi mais marcou na competição {competicao}"))
  plt.show()

# %% [markdown]
# # 3.2 Quais tipos de gols Messi mais marcou?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# import mplcursors
df = pd.read_csv("data/messi.csv")
tipo_gols = df['tipo'].value_counts()
tipo_gol= tipo_gols.head(10) 
fig, ax = plt.subplots()
barras = ax.bar(tipo_gol.index, tipo_gol)

# Adicionar as quantidades sobre cada barra
for barra in barras:
    altura = barra.get_height()
    ax.annotate(f'{altura}', xy=(barra.get_x() + barra.get_width() / 2, altura),
                xytext=(0, 3), textcoords='offset points', ha='center', va='bottom')

plt.xlabel('Tipos de Gols')
plt.ylabel('Quantidade')
plt.title('Tipos de Gols mais Marcados Por Lionel Messi')
plt.xlim(-0.5, len(tipo_gol) - 0.5)
plt.xticks(rotation=45, ha='right')
plt.ylim(0, tipo_gol.max() * 1.1) 
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3.3 Quantos gols em cada período (primeiro ou segundo tempo) Messi marcou?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('data/messi.csv')
df['minuto'] = pd.to_numeric(df['minuto'], errors='coerce')

# Criar intervalos personalizados
intervals = [1, 45 , 91, 120]

# Definir os rótulos das faixas
labels = ['Primeiro Tempo', 'Segundo Tempo', 'Prorrogação']

# Adicionar uma nova coluna com as faixas
df['faixa_minuto'] = pd.cut(df['minuto'], bins=intervals, labels=labels, right=False)

# Contar a quantidade de vezes que cada faixa se repete
contador = df['faixa_minuto'].value_counts().sort_index()

# Converter os dados do contador para uma matriz
matriz_contador = np.array(contador).reshape(1, -1)

# Plotar o gráfico de calor
fig, ax = plt.subplots()
im = ax.imshow(matriz_contador, cmap='YlOrRd')

# Adicionar os valores sobre cada célula do gráfico de calor
for i in range(matriz_contador.shape[0]):
    for j in range(matriz_contador.shape[1]):
        text = ax.text(j, i, matriz_contador[i, j], ha='center', va='center', color='black')

# Definir os rótulos do eixo x e y
ax.set_xticks(np.arange(len(labels)))
ax.set_yticks([0])
ax.set_xticklabels(labels)
ax.set_yticklabels(['Quantidade'])

# Definir o título do gráfico
ax.set_title('Quantidade de Gols de Lionel Messi em Etapas da Partida', fontsize=10)

# Ajustar o espaçamento inferior
plt.subplots_adjust(bottom=0.02)

# Adicionar uma barra de cores
cbar = ax.figure.colorbar(im, ax=ax, aspect=50)

plt.show()

# %% [markdown]
# # 3.4 Em quais faixas de minuto (divididos a cada 15 minutos) Messi mais marcou?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('data/messi.csv')
df['minuto'] = pd.to_numeric(df['minuto'], errors='coerce')

# Criar intervalos personalizados
intervals = [1, 15, 30, 45, 60, 75, 91, 105, 120]

# Definir os rótulos das faixas
labels = ['1-15', '16-30', '31-45', '46-60', '61-75', '76-90', '91-105', '105-120']

# Adicionar uma nova coluna com as faixas
df['faixa_minuto'] = pd.cut(df['minuto'], bins=intervals, labels=labels, right=False)

# Contar a quantidade de vezes que cada faixa se repete
contador = df['faixa_minuto'].value_counts().sort_index()

# Converter os dados do contador para uma matriz
matriz_contador = np.array(contador).reshape(1, -1)

# Plotar o gráfico de calor
fig, ax = plt.subplots()
im = ax.imshow(matriz_contador, cmap='YlOrRd')

# Adicionar os valores sobre cada célula do gráfico de calor
for i in range(matriz_contador.shape[0]):
    for j in range(matriz_contador.shape[1]):
        text = ax.text(j, i, matriz_contador[i, j], ha='center', va='center', color='black')

# Definir os rótulos do eixo x e y
ax.set_xticks(np.arange(len(labels)))
ax.set_yticks([0])
ax.set_xticklabels(labels)
ax.set_yticklabels(['Quantidade'])

# Definir o título do gráfico
ax.set_title('Quantidade de Gols de Lionel Messi: Faixas de 15 Minutos', fontsize=10)

# Ajustar o espaçamento inferior
plt.subplots_adjust(bottom=0.02)

# Adicionar uma barra de cores
cbar = ax.figure.colorbar(im, ax=ax, aspect=50)

plt.show()

# %% [markdown]
# # 3.5 Quais jogadores deram mais assistências para gols de Lionel Messi?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("data/messi.csv")
maiores_assistentes = df['jogador_assistente'].value_counts()
maiores_assistentes= maiores_assistentes.head(10) 
fig, ax = plt.subplots()
barras = ax.bar(maiores_assistentes.index, maiores_assistentes)

# Adicionar as quantidades sobre cada barra
for barra in barras:
    altura = barra.get_height()
    ax.annotate(f'{altura}', xy=(barra.get_x() + barra.get_width() / 2, altura),
                xytext=(0, 3), textcoords='offset points', ha='center', va='bottom')

plt.xlabel('Jogador Assistente')
plt.ylabel('Quantidade')
plt.title('Maiores Assistentes de Lionel Messi')
plt.xlim(-0.5, len(maiores_assistentes) - 0.5)
plt.xticks(rotation=45, ha='right')
plt.ylim(0, maiores_assistentes.max() * 1.1) 
plt.tight_layout()
plt.show()
